# %% [markdown]
# # One solve, many questions: `wrt=` blocks, uncertainty bands, `retain_kkt()`
#
# When POUNCE solves a nonlinear program (NLP, an optimization problem
# with nonlinear equations in it), it builds the KKT matrix, the matrix
# of equations that characterize the optimum (KKT is short for
# Karush-Kuhn-Tucker), and factorizes it, meaning it does the expensive
# matrix preparation once so that solving against it afterwards is
# cheap. POUNCE keeps that factorization in memory after the solve, and
# every uncertainty question in this notebook is answered against it,
# nearly for free. `wrt=` points `covariance()` and `information()` at
# any subset of the problem's variables (a "block"): a few of the
# fitted parameters, the model's predicted values, a question about
# what stays uncertain while a variable sits at its limit. With
# `retain_kkt()` the factorization is kept even when nothing was
# flagged with the `declare_*` functions, for problems where no subset
# is THE fitted set.

# %% [markdown]
# The example used throughout is a single-exponential fit. The model
# predicts
#
# $$\hat y_i = A\; e^{-k t_i},$$
#
# where each predicted value $\hat y_i$ is an explicit variable of the
# solve, constrained to equal the curve at data point $i$. The residual
# variables carry the misfit against the measurements $y_i$, and the
# objective minimizes their squares:
#
# $$r_i = y_i - \hat y_i,\qquad \min \sum_i r_i^2.$$
#
# Only $(A, k)$ are declared fitted; the $\hat y_i$ and $r_i$ are
# ordinary variables the solve determines.

# %%
import textwrap
import warnings

import numpy as np
import matplotlib.pyplot as plt
import pyomo.environ as pyo

import pyomo_pounce
from pyomo_pounce import (
    covariance, declare_fitted, declare_residual, information,
    release_kkt, retain_kkt)

rng = np.random.default_rng(4)
A_TRUE, K_TRUE, SIG_TRUE = 2.0, 0.9, 0.05
t_data = np.linspace(0.0, 4.0, 30)
y_data = (A_TRUE * np.exp(-K_TRUE * t_data)
          + SIG_TRUE * rng.standard_normal(len(t_data)))


def build(t, y, declare=True):
    m = pyo.ConcreteModel()
    m.I = pyo.RangeSet(0, len(t) - 1)
    m.A = pyo.Var(initialize=1.0)
    m.k = pyo.Var(initialize=1.0)
    m.yhat = pyo.Var(m.I, initialize=1.0)
    m.r = pyo.Var(m.I, initialize=0.0)

    @m.Constraint(m.I)
    def prediction(mm, i):
        return mm.yhat[i] == mm.A * pyo.exp(-mm.k * float(t[i]))

    @m.Constraint(m.I)
    def residual(mm, i):
        return mm.r[i] == float(y[i]) - mm.yhat[i]

    m.obj = pyo.Objective(expr=sum(m.r[i] ** 2 for i in m.I))
    if declare:
        declare_fitted(m.A, m.k)
        declare_residual(m.r)
    return m

m = build(t_data, y_data)
pyo.SolverFactory("pounce").solve(m, tee=True)
cov = covariance(m)
print(f"A = {pyo.value(m.A):.4f} +/- {cov.std_err[m.A]:.4f}")
print(f"k = {pyo.value(m.k):.4f} +/- {cov.std_err[m.k]:.4f}")
# Out:
# ********************************************************************************
#
#                     ####    ###   /   # /#   #/  ####  #####
#                     #   #  #   # /#   #/ ##  /  #      #
#                     ####   #   #/ #   /  # #/#  #      ####
#                     #      #   /  #  /#  # /##  #      #
#                     #       ##/    #/#   #/  #   ####  #####
#
# ********************************************************************************
# This program contains POUNCE, a pure-Rust interior-point optimization solver
# for nonlinear, conic, and global problems (its NLP core is ported from Ipopt).
# Released under the Eclipse Public License (EPL) — drop-in compatible with Ipopt.
#          For more information visit https://github.com/jkitchin/pounce
# ********************************************************************************
#
# This is POUNCE version 0.9.0, running with linear solver FERAL.
# ...

# %% [markdown]
# ## 1. Sub-block marginals
#
# Each `wrt=` call asks the kept factorization about a different
# subset: one solve, as many questions as you like. The answer for a
# block is its marginal uncertainty, with everything outside the block
# allowed to adjust rather than held fixed. A sub-block's marginal
# equals the corresponding entry of the no-argument `covariance(m)`
# exactly, because the noise level sigma is estimated once from the fit
# itself, dividing by its degrees of freedom (data points minus fitted
# parameters), and does not change with the question being asked.

# %%
cov_A = covariance(m, wrt=[m.A])
print(f"marginal via wrt=[A]: {cov_A[m.A]:.6g}")
print(f"entry of the default: {cov[m.A]:.6g}")
info_A = information(m, wrt=[m.A])
print(f"\ninformation marginal of A alone: {info_A[m.A]:.6g}")
print(f"sibling identity  cov*info = 2 sigma^2: "
      f"{cov_A[m.A] * info_A[m.A]:.6g} vs {2 * cov.sigma_sq:.6g}")
# Out:
# marginal via wrt=[A]: 0.00132948
# entry of the default: 0.00132948
#
# information marginal of A alone: 5.05951
# sibling identity  cov*info = 2 sigma^2: 0.00672651 vs 0.00672651

# %% [markdown]
# ## 2. Two uncertainty bands from one `wrt=` block
#
# The model carries its predicted values as ordinary variables: each
# `yhat[i]` is constrained to equal the curve at one data point, and
# nothing at all was declared about them. `wrt=` can still ask about
# them, and their covariance is the sampling uncertainty of the FITTED
# CURVE: plotting +/- 2 standard errors around the fit gives the
# CONFIDENCE band on the mean response (a standard error is the square
# root of a variance). That band says where the true curve plausibly
# lies; it is not supposed to contain the data points, because each
# measurement also carries its own observation noise. Adding that
# noise, `sqrt(se^2 + sigma^2)`, widens it into the PREDICTION band,
# which says where a new measurement would plausibly land; the figure
# shows both. This block has 30 coordinates while the fit has only 2
# free parameters, so its covariance has rank 2: rank-deficient,
# carrying fewer independent directions than rows. That is fine for a
# covariance, which is read directly off the inverse KKT matrix with
# nothing inverted. For the same reason, asking `information()` about
# this block raises an error, shown below, instead of returning a
# meaningless matrix: information would be the inverse of that
# covariance, and a rank-deficient matrix has no inverse.

# %%
band = covariance(m, wrt=m.yhat)
se = np.sqrt(np.diag(band.matrix))
fit = np.array([pyo.value(m.yhat[i]) for i in m.I])
sig_hat = float(np.sqrt(cov.sigma_sq))
se_pred = np.sqrt(se**2 + sig_hat**2)

plt.figure(figsize=(7, 4))
plt.fill_between(t_data, fit - 2 * se_pred, fit + 2 * se_pred,
                 alpha=0.2,
                 label="prediction band: fit +/- 2 sqrt(se^2 + sigma^2)")
plt.fill_between(t_data, fit - 2 * se, fit + 2 * se,
                 alpha=0.45,
                 label="confidence band on the curve: fit +/- 2 se")
plt.plot(t_data, fit, label="fit")
plt.plot(t_data, y_data, "k.", ms=4, label="data")
plt.xlabel("t"); plt.ylabel("y"); plt.legend(); plt.tight_layout()
plt.show()

try:
    information(m, wrt=m.yhat)
except RuntimeError as e:
    print("information(m, wrt=m.yhat) raises an error:")
    print(textwrap.fill(str(e), width=72, initial_indent="  ",
                        subsequent_indent="  "))
# Out:
# information(m, wrt=m.yhat) raises an error:
#   information: the wrt block is rank-deficient (more coordinates than
#   the fit has degrees of freedom), so it carries no information matrix;
#   its covariance (covariance(model, wrt=...)) is the meaningful object
#   for such a block

# %% [markdown]
# ## 3. `conditioned_on`: the answer's conditioning, returned
#
# Pin `A` at a bound (a limit the solution presses against) and ask
# about `k` alone. The block's number is the value conditional on that
# bound, computed as if `A` were clamped there, not the marginal over
# it. And the result SAYS so: the variables held at their bounds
# outside the block (strongly active, in the solver's language) come
# back on `conditioned_on`, so the conditioning travels with the answer
# instead of living in the caller's head.

# %%
m2 = build(t_data, y_data)
m2.A.setlb(pyo.value(m.A) + 0.2)
with warnings.catch_warnings(record=True):
    warnings.simplefilter("always")
    pyo.SolverFactory("pounce").solve(m2)
cov_k = covariance(m2, wrt=[m2.k])
print(f"var(k) conditional on the bound: {cov_k[m2.k]:.6g}")
print("conditioned on:", [v.name for v in cov_k.conditioned_on])
# Out:
# var(k) conditional on the bound: 0.000821034
# conditioned on: ['A']

# %% [markdown]
# The picture below shows how uncertain the predicted value is at each
# time. The height of a curve at $t$ is 2 standard errors of
# $\hat y(t)$, the same quantity that set the edges of section 2's
# confidence band. For the free fit the uncertainty is largest at $t = 0$,
# because the prediction there equals `A` and `A` is uncertain, and it
# falls as the decaying shape lets the data pin later points more
# tightly. For the pinned solve it is zero to solver tolerance at $t = 0$,
# because
# with `A` clamped the prediction there is fully determined given the
# bound, and it rises to a bump near $t = 1$, where the predictions are
# most sensitive to `k` and `k` now carries all the remaining
# uncertainty. Mid-curve the pinned uncertainty exceeds the free one
# for a second reason stacked on top: the noise level is re-estimated
# from the pinned solve's own residuals, which are larger because the
# bound displaces the fit, and that inflates its whole curve.

# %%
band_pin = covariance(m2, wrt=m2.yhat)
se_pin = np.sqrt(np.diag(band_pin.matrix))

plt.figure(figsize=(7, 4))
plt.plot(t_data, 2 * se, label="free fit")
plt.plot(t_data, 2 * se_pin, "--", label="A held at its bound")
plt.xlabel("t")
plt.ylabel("2 standard errors of the predicted value")
plt.legend(); plt.tight_layout()
plt.show()
print("conditioned on:", [v.name for v in band_pin.conditioned_on])
# Out:
# conditioned on: ['A']

# %% [markdown]
# ## 4. `retain_kkt()`: asking questions with nothing declared
#
# This pattern comes from moving horizon estimation (MHE), a control
# method that re-solves an estimation problem every few seconds. There,
# no single set of variables is THE fitted set: one moment you ask
# about the current state estimate, the next about the model
# parameters, each with its own `wrt=`. `retain_kkt(model)` keeps the
# factorization with no declaration at all. `covariance(model)` without
# a block stays an error, since no block was ever named as the default,
# and a solve without the call and without declarations pays nothing,
# exactly as before.

# %%
m3 = build(t_data, y_data, declare=False)
retain_kkt(m3)
pyo.SolverFactory("pounce").solve(m3)

s2 = float(cov.sigma_sq)          # noise from the declared fit above
info_params = information(m3, wrt=[m3.A, m3.k])
print("parameter information via retain_kkt only:")
print(np.array2string(info_params.matrix, precision=3))

band3 = covariance(m3, sigma_sq=s2, wrt=m3.yhat)
print()
print("band from the undeclared solve matches:",
      f"{np.max(np.abs(band3.matrix - band.matrix)):.2e}")

try:
    covariance(m3, sigma_sq=s2)
except RuntimeError as e:
    print()
    print("covariance(m3) without wrt raises an error:")
    print(textwrap.fill(str(e), width=72, initial_indent="  ",
                        subsequent_indent="  "))
# Out:
# parameter information via retain_kkt only:
# [[ 9.024 -8.718]
#  [-8.718 19.169]]
#
# band from the undeclared solve matches: 0.00e+00
#
# covariance(m3) without wrt raises an error:
#   covariance: no fitted parameters were declared; flag the fitted
#   variables with declare_fitted() before the solve, or select a block
#   explicitly with wrt=

# %% [markdown]
# The retention story also has an exit. `release_kkt(model)` drops the
# model's hold on the factorization immediately, freeing its memory;
# the accessors raise their no-session error until another solve, and
# declarations or a prior `retain_kkt()` still apply to that next
# solve.

# %%
print("released:", release_kkt(m3))
try:
    information(m3, wrt=[m3.A, m3.k])
except RuntimeError as e:
    print(textwrap.fill(str(e), width=72, initial_indent="  ",
                        subsequent_indent="  "))
# Out:
# released: True
#   no sensitivity session: declare_fitted() (and optionally
#   declare_residual()), or retain_kkt() for wrt= queries with nothing
#   declared, then solve with SolverFactory('pounce') first

# %% [markdown]
# One policy covers retention: the factorization is kept if anything is
# declared or `retain_kkt()` was called, and released on demand with
# `release_kkt()`. A `Covariance` or `Information` result computes its
# `conditioned_on` list only when the attribute is first read; until
# then the result keeps the solver session, and with it the
# factorization, in memory. An undeclared solve without the call pays
# nothing.
